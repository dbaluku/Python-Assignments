# %% [markdown]
# NAME: BALUKU DERRICK
# REG NO : MAY22/MCOMP/1616U

# %% [markdown]
# # Question Four

# %%
import os
import cv2
import matplotlib.pyplot as plt

my_image = "FRFW7d_XwAAoG8a.jpeg"
cwd = os.getcwd()
image_path = os.path.join(cwd, my_image)

image = cv2.imread(image_path)
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (1033, 1080, 3)

# %%
image.max()
# Out:
# 255

# %%
scale_percent = 60 # percent of original size
width = int(680)
height = int(633)
dim = (width, height)

# resize image
resized = cv2.resize(image, dim,interpolation= cv2.INTER_LINEAR)
plt.figure(figsize=(10,10))
plt.imshow(resized)
plt.show()

# %% [markdown]
# # Question Five

# %%
resized.shape
# Out:
# (633, 680, 3)

# %%
another_image = cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
resized = cv2.resize(another_image, dim,interpolation= cv2.INTER_LINEAR)
plt.figure(figsize=(10,10))
plt.imshow(resized,cmap='winter')
plt.show()
